# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviredu/PowerBI/blob/main/SKIN_LESION_WITH_CUSTOM_RESUNET_ARCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'ph2dataset:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F747058%2F1293025%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240725%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240725T033927Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading ph2dataset, 424765398 bytes compressed
# [==================================================] 424765398 bytes downloaded
# Downloaded and uncompressed: ph2dataset
# Data source import complete.

# %%
# !pip install torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchviz) (2.3.1+cu121)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from torchviz) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->torchviz)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->torchviz)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->torchviz)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->torchviz)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->torchviz)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->torchviz)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->torchviz)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->torchviz)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->torchviz)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->torchviz)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->torchviz)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->torchviz)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchviz) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchviz) (1.3.0)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 14.7 MB/s eta 0:00:00
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4132 sha256=1b84d21167468c11b2cdf9ff085ff6abf1657cb62ce0da9344752a70105f09ff
#   Stored in directory: /root/.cache/pip/wheels/4c/97/88/a02973217949e0db0c9f4346d154085f4725f99c4f15a87094
# Successfully built torchviz
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchviz
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 torchviz-0.0.2

# %%
import os
import glob
import cv2
import warnings
import random
import torch
import torch.nn               as nn
import pandas                 as pd
import numpy                  as np
import matplotlib.pyplot      as plt
import seaborn                as sns
import torch.optim            as optim
import torchvision.transforms as transforms
from torchviz         import make_dot
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from PIL              import Image
from torch.utils.data import Dataset
from torchvision      import transforms
from PIL              import Image
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split

# %%
IMAGE_SIZE = 128
BATCH_SIZE = 16
DEVICE     = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=0)

# %%
class Extract:
    def get_mask(self):
        folder_path1 = "../input/ph2dataset/trainy/*.bmp"
# List all files in the folder
        files1 = glob.glob(folder_path1)
        #sorted_files1 = sorted(files1, key=lambda x: int(x.split('.')[0][5:]))
        files1.sort()
        #self.mask = [os.path.join(folder_path1, f) for f in sorted_files1[:400]]
        self.mask = files1
        return self.mask
    def get_actual(self):
        folder_path2 = "../input/ph2dataset/trainx/*.bmp"
        # List all files in the folder
        files2 = glob.glob(folder_path2)
        #sorted_files2 = sorted(files2, key=lambda x: int(x.split('.')[0][5:]))
        files2.sort()
        #self.images = [os.path.join(folder_path2, f) for f in sorted_files2[:400]]
        self.images = files2
        return self.images
    def get_all(self):
        m = self.get_mask()
        a = self.get_actual()
        self.image_mask = list(zip(a,m))
        return self.image_mask
    def dataframe_conversion(self):
        self.series = self.get_all()
        self.df = pd.DataFrame(self.series, columns=['image_path', 'mask_path'])
        return self.df

    def plot_train_label(self,image_mask):
        image = cv2.imread(image_mask[0])
        mask = cv2.imread(image_mask[1])
        f, axarr = plt.subplots(1, 3, figsize=(5, 5))
        axarr[0].imshow(np.squeeze(image), cmap='gray', origin='lower')
        axarr[0].set_ylabel('Axial View', fontsize=14)
        axarr[0].set_xticks([])
        axarr[0].set_yticks([])
        axarr[0].set_title('CT', fontsize=14)

        axarr[1].imshow(np.squeeze(mask), cmap='jet', origin='lower')
        axarr[1].axis('off')
        axarr[1].set_title('Mask', fontsize=14)

        axarr[2].imshow(np.squeeze(image), cmap='gray', alpha=1, origin='lower')
        axarr[2].imshow(np.squeeze(mask), cmap='jet', alpha=0.5, origin='lower')
        axarr[2].axis('off')
        axarr[2].set_title('Overlay', fontsize=14)

        plt.tight_layout()
        plt.subplots_adjust(wspace=0, hspace=0)
        plt.show()

# %%
ETL = Extract()
images_mask = ETL.get_all()

# %%
class CustomImageTransform(Dataset):
    def __init__(self,image_mask,transformMethodName = None):
        self.data            = image_mask
        self.transformMethod = transformMethodName

    def __len__(self):
        return len(self.data)

    def __getitem__(self,idx):
        image_path = self.data.iloc[idx]['image_path']
        mask_path  = self.data.iloc[idx]['mask_path']

        image      = Image.open(image_path).convert("L")
        mask       = Image.open(mask_path).convert("L")

        if self.transformMethod:
            image  = self.transformMethod(image)
            mask   = self.transformMethod(mask)

        return image,mask

# %%
class ConvBlock(nn.Module):
    def __init__(self,input_channel,out_channel,dropout):
        super(ConvBlock,self).__init__()
        self.CONV2D1    = nn.Conv2d(input_channel,out_channel,kernel_size=3,padding=1)
        self.BATCHNORN1 = nn.BatchNorm2d(out_channel)
        self.RELU1      = nn.ReLU()
        self.DROPOUT    = nn.Dropout(dropout)
        self.CONV2D2    = nn.Conv2d(out_channel,out_channel,kernel_size=3,padding=1)
        self.BATCHNORN2 = nn.BatchNorm2d(out_channel)
        self.RELU2      = nn.ReLU()

    def forward(self,x):
        """ IN CONV2D PYTORCH MODULE YOU DONT NEED TO GIVE THE OUTPUT CHANNEL PARAMETER VALUE
            BUT THE PARAMETER HAVE TO BE THERE"""
        x = self.CONV2D1(x)
        x = self.BATCHNORN1(x)
        x = self.RELU1(x)
        x = self.DROPOUT(x)
        x = self.CONV2D2(x)
        x = self.BATCHNORN2(x)
        x = self.RELU2(x)
        return x

# %%
class ENCODER(nn.Module):
    def __init__(self,input_channel,out_channel,dropout):
        super(ENCODER,self).__init__()
        self.CONV2D1  = ConvBlock(input_channel,out_channel,dropout)
        self.MAXPOOL1 = nn.MaxPool2d((2,2))
        self.DROPOUT1 = nn.Dropout(dropout)

    def forward(self,x):
        x = self.CONV2D1(x)
        p = self.MAXPOOL1(x)
        p = self.DROPOUT1(p)

        return x,p

# %%
class DECODER(nn.Module):
    def __init__(self,input_channel,out_channel,dropout):
        super(DECODER,self).__init__()
        self.CONVTRANSPOSE1 = nn.ConvTranspose2d(input_channel,out_channel,stride=2,kernel_size=2)
        ## THE CONVTRANSPOSE UPSAMPLES THE SAYER BY 2 AND SAVE IT TO THE OUTCHANNEL
        ## THATHS WHY FOR FURTHER CONVOLUTION WE MULTIPLY THE OUTCHANNEL BY 2
        self.CONV2D1        = ConvBlock(out_channel*2,out_channel,dropout)
        self.DROPOUT        = nn.Dropout(dropout)

    def forward(self,x,skip):
        x = self.CONVTRANSPOSE1(x)
        x = torch.cat([x,skip],dim=1)
        x = self.CONV2D1(x)
        x = self.DROPOUT(x)


        return x

# %%
class UNET(nn.Module):
    def __init__(self,input_channel = 1): ## GRAYSCALE IMAGE
        super().__init__()
        self.ENCODER1  = ENCODER(input_channel,64,0.07)
        self.ENCODER2  = ENCODER(64,128,0.08)
        self.ENCODER3  = ENCODER(128,256,0.09)
        self.ENCODER4  = ENCODER(256,512,0.01)
        self.CONVBLOCK = ConvBlock(512,1024,0.11)
        self.DECODER1  = DECODER(1024,512,0.1)
        self.DECODER2  = DECODER(512,256,0.09)
        self.DECODER3  = DECODER(256,128,0.08)
        self.DECODER4  = DECODER(128,64,0.07)
        self.CLS       = nn.Conv2d(64,1,kernel_size=1,padding=0)
        self.ACTFN     = nn.Sigmoid()

    def forward(self,x):
        x1,p1   = self.ENCODER1(x)
        x2,p2   = self.ENCODER2(p1)
        x3,p3   = self.ENCODER3(p2)
        x4,p4   = self.ENCODER4(p3)

        x5      = self.CONVBLOCK(p4)

        x6      = self.DECODER1(x5,x4)
        x7      = self.DECODER2(x6,x3)
        x8      = self.DECODER3(x7,x2)
        x9      = self.DECODER4(x8,x1)

        x_FINAL = self.CLS(x9)
        x_FINAL = self.ACTFN(x_FINAL)

        return x_FINAL

# %%
class Trainer:
    def __init__(self, model, num_epoch, optimizer, criterion, device):
        self.NUM_EPOCH = num_epoch
        self.OPTIMIZER = optimizer
        self.CRITERION = criterion
        self.MODEL = model
        self.device = device
        self.LOG_INTRVL = 15

        self.TRAIN_LOSSES = []
        self.VAL_LOSSES = []
        self.TRAIN_DICES = []
        self.VAL_DICES = []

        self.BEST_MODEL = None
        self.BEST_DICE = 0
        self.BEST_EPOCH = 0

    def DICE_COEFF(self, predicted, target, smooth=1e-5):
        INTERSECTION = torch.sum(predicted * target)
        UNION = torch.sum(predicted) + torch.sum(target)
        DICE = (2. * INTERSECTION + smooth) / (UNION + smooth)
        return DICE

    def IOU(self, pred_mask, true_mask):
        INTERSECTION = torch.logical_and(pred_mask, true_mask).sum().item()
        UNION = torch.logical_or(pred_mask, true_mask).sum().item()
        IOU_SCORE = INTERSECTION / UNION if UNION != 0 else 0.0
        return IOU_SCORE

    def train(self, train_loader, val_loader):
        for epoch in range(self.NUM_EPOCH):
            TRAIN_LOSS = 0.0
            VAL_LOSS = 0.0
            TRAIN_DICE = 0.0
            VAL_DICE = 0.0

            for i, (images, masks) in enumerate(train_loader):
                images, masks = images.to(self.device), masks.to(self.device)
                self.MODEL.train()
                self.OPTIMIZER.zero_grad()
                outputs = self.MODEL(images)
                loss = self.CRITERION(outputs, masks)
                dice = self.DICE_COEFF(outputs, masks)
                loss.backward()
                self.OPTIMIZER.step()
                TRAIN_LOSS += loss.item()
                TRAIN_DICE += dice
                print(f'Epoch [{epoch + 1}/{self.NUM_EPOCH}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}, Dice Coef: {dice:.4f}')

            # Validation
            self.MODEL.eval()
            with torch.no_grad():
                for images, masks in val_loader:
                    images, masks = images.to(self.device), masks.to(self.device)
                    outputs = self.MODEL(images)
                    VAL_LOSS += self.CRITERION(outputs, masks).item()
                    VAL_DICE += self.DICE_COEFF(outputs, masks)

            avg_train_loss = TRAIN_LOSS / len(train_loader)
            avg_val_loss = VAL_LOSS / len(val_loader)
            avg_train_dice = TRAIN_DICE / len(train_loader)
            avg_val_dice = VAL_DICE / len(val_loader)

            self.TRAIN_LOSSES.append(avg_train_loss)
            self.VAL_LOSSES.append(avg_val_loss)
            self.TRAIN_DICES.append(avg_train_dice)
            self.VAL_DICES.append(avg_val_dice)

    def get_metrics(self):
        return {
            'train_losses': self.TRAIN_LOSSES,
            'val_losses': self.VAL_LOSSES,
            'train_dices': self.TRAIN_DICES,
            'val_dices': self.VAL_DICES,
            'best_dice': self.BEST_DICE,
            'best_epoch': self.BEST_EPOCH
        }

# %%
class LossFunctions:
    @staticmethod
    def dice_coef_loss(inputs, target):
        smooth = 1e-6
        intersection = 2.0 * (target * inputs).sum() + smooth
        union = target.sum() + inputs.sum() + smooth
        return 1 - (intersection / union)

    @staticmethod
    def bce_dice_loss(inputs, target):
        dice_score = LossFunctions.dice_coef_loss(inputs, target)
        bce_loss = nn.BCELoss()
        bce_score = bce_loss(inputs, target)
        return bce_score + dice_score

# %%
random_image = random.sample(range(200), 7)
for image in random_image:
    ETL.plot_train_label(images_mask[image])

# %%
dataset = ETL.dataframe_conversion()
dataset
# Out:
#                                 image_path  \
# 0    ../input/ph2dataset/trainx/IMD002.bmp
# 1    ../input/ph2dataset/trainx/IMD003.bmp
# 2    ../input/ph2dataset/trainx/IMD004.bmp
# 3    ../input/ph2dataset/trainx/IMD006.bmp
# 4    ../input/ph2dataset/trainx/IMD008.bmp
# ..                                     ...
# 195  ../input/ph2dataset/trainx/IMD433.bmp
# 196  ../input/ph2dataset/trainx/IMD434.bmp
# 197  ../input/ph2dataset/trainx/IMD435.bmp
# 198  ../input/ph2dataset/trainx/IMD436.bmp
# 199  ../input/ph2dataset/trainx/IMD437.bmp
#
#                                         mask_path
# 0    ../input/ph2dataset/trainy/IMD002_lesion.bmp
# 1    ../input/ph2dataset/trainy/IMD003_lesion.bmp
# 2    ../input/ph2dataset/trainy/IMD004_lesion.bmp
# 3    ../input/ph2dataset/trainy/IMD006_lesion.bmp
# 4    ../input/ph2dataset/trainy/IMD008_lesion.bmp
# ..                                            ...
# 195  ../input/ph2dataset/trainy/IMD433_lesion.bmp
# 196  ../input/ph2dataset/trainy/IMD434_lesion.bmp
# 197  ../input/ph2dataset/trainy/IMD435_lesion.bmp
# 198  ../input/ph2dataset/trainy/IMD436_lesion.bmp
# 199  ../input/ph2dataset/trainy/IMD437_lesion.bmp
#
# [200 rows x 2 columns]

# %%
train_transforms = transforms.Compose([
    transforms.Resize([IMAGE_SIZE, IMAGE_SIZE]),
    transforms.ToTensor(),
])

val_transforms = transforms.Compose([
    transforms.Resize([IMAGE_SIZE, IMAGE_SIZE]),
    transforms.ToTensor(),
])

# %%
train, test= train_test_split(dataset, test_size=0.25)

# %%
train_dataset = CustomImageTransform(train, train_transforms)
test_dataset = CustomImageTransform(test, val_transforms)

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
unet = UNET(1).to(DEVICE)

# %%
LR           = 0.0001
OPTIMIZER    = optim.Adam(unet.parameters(),lr=LR)
trainer      = Trainer(model=unet,num_epoch=100,optimizer=OPTIMIZER,criterion=LossFunctions.bce_dice_loss,device=DEVICE)

# %%
trainer.train(train_dataloader,test_dataloader)
# Out:
# Epoch [1/100], Step [1/10], Loss: 1.3154, Dice Coef: 0.4387
# Epoch [1/100], Step [2/10], Loss: 1.2884, Dice Coef: 0.4179
# Epoch [1/100], Step [3/10], Loss: 1.1699, Dice Coef: 0.4809
# Epoch [1/100], Step [4/10], Loss: 1.0478, Dice Coef: 0.5355
# Epoch [1/100], Step [5/10], Loss: 1.0387, Dice Coef: 0.5519
# Epoch [1/100], Step [6/10], Loss: 0.9651, Dice Coef: 0.5757
# Epoch [1/100], Step [7/10], Loss: 0.9803, Dice Coef: 0.5696
# Epoch [1/100], Step [8/10], Loss: 0.9272, Dice Coef: 0.5923
# Epoch [1/100], Step [9/10], Loss: 1.0399, Dice Coef: 0.5186
# Epoch [1/100], Step [10/10], Loss: 0.9530, Dice Coef: 0.5601
# Epoch [2/100], Step [1/10], Loss: 0.8038, Dice Coef: 0.6643
# Epoch [2/100], Step [2/10], Loss: 0.8610, Dice Coef: 0.6056
# Epoch [2/100], Step [3/10], Loss: 0.8054, Dice Coef: 0.6287
# Epoch [2/100], Step [4/10], Loss: 0.8809, Dice Coef: 0.5710
# Epoch [2/100], Step [5/10], Loss: 0.6529, Dice Coef: 0.6929
# Epoch [2/100], Step [6/10], Loss: 0.8867, Dice Coef: 0.5756
# Epoch [2/100], Step [7/10], Loss: 0.6587, Dice Coef: 0.6935
# Epoch [2/100], Step [8/10], Loss: 0.7377, Dice Coef: 0.6395
# Epoch [2/100], Step [9/10], Loss: 0.7188, Dice Coef: 0.6506
# Epoch [2/100], Step [10/10], Loss: 0.8189, Dice Coef: 0.5862
# Epoch [3/100], Step [1/10], Loss: 0.7171, Dice Coef: 0.6419
# Epoch [3/100], Step [2/10], Loss: 0.7346, Dice Coef: 0.6312
# Epoch [3/100], Step [3/10], Loss: 0.8459, Dice Coef: 0.5977
# Epoch [3/100], Step [4/10], Loss: 0.6340, Dice Coef: 0.6857
# Epoch [3/100], Step [5/10], Loss: 0.5748, Dice Coef: 0.7212
# Epoch [3/100], Step [6/10], Loss: 0.6118, Dice Coef: 0.7265
# Epoch [3/100], Step [7/10], Loss: 0.8102, Dice Coef: 0.6001
# Epoch [3/100], Step [8/10], Loss: 0.5306, Dice Coef: 0.7471
# Epoch [3/100], Step [9/10], Loss: 0.6103, Dice Coef: 0.7095
# Epoch [3/100], Step [10/10], Loss: 0.5378, Dice Coef: 0.7582
# Epoch [4/100], Step [1/10], Loss: 0.6391, Dice Coef: 0.6890
# Epoch [4/100], Step [2/10], Loss: 0.6467, Dice Coef: 0.6853
# Epoch [4/100], Step [3/10], Loss: 0.7755, Dice Coef: 0.6139
# Epoch [4/100], Step [4/10], Loss: 0.4980, Dice Coef: 0.7645
# Epoch [4/100], Step [5/10], Loss: 0.5046, Dice Coef: 0.7736
# Epoch [4/100], Step [6/10], Loss: 0.5237, Dice Coef: 0.7543
# Epoch [4/100], Step [7/10], Loss: 0.5746, Dice Coef: 0.7261
# Epoch [4/100], Step [8/10], Loss: 0.5414, Dice Coef: 0.7464
# Epoch [4/100], Step [9/10], Loss: 0.8256, Dice Coef: 0.6035
# Epoch [4/100], Step [10/10], Loss: 0.6838, Dice Coef: 0.6455
# Epoch [5/100], Step [1/10], Loss: 0.5949, Dice Coef: 0.7007
# Epoch [5/100], Step [2/10], Loss: 0.5388, Dice Coef: 0.7322
# Epoch [5/100], Step [3/10], Loss: 0.5850, Dice Coef: 0.7291
# Epoch [5/100], Step [4/10], Loss: 0.8754, Dice Coef: 0.5828
# Epoch [5/100], Step [5/10], Loss: 0.5292, Dice Coef: 0.7443
# Epoch [5/100], Step [6/10], Loss: 0.6541, Dice Coef: 0.6661
# Epoch [5/100], Step [7/10], Loss: 0.5786, Dice Coef: 0.7146
# Epoch [5/100], Step [8/10], Loss: 0.5781, Dice Coef: 0.7089
# Epoch [5/100], Step [9/10], Loss: 0.5874, Dice Coef: 0.7120
# Epoch [5/100], Step [10/10], Loss: 0.5110, Dice Coef: 0.7643
# Epoch [6/100], Step [1/10], Loss: 0.4820, Dice Coef: 0.7717
# Epoch [6/100], Step [2/10], Loss: 0.5608, Dice Coef: 0.7314
# Epoch [6/100], Step [3/10], Loss: 0.4941, Dice Coef: 0.7643
# Epoch [6/100], Step [4/10], Loss: 0.5747, Dice Coef: 0.7240
# Epoch [6/100], Step [5/10], Loss: 0.6852, Dice Coef: 0.6707
# Epoch [6/100], Step [6/10], Loss: 0.4782, Dice Coef: 0.7676
# Epoch [6/100], Step [7/10], Loss: 0.5508, Dice Coef: 0.7315
# Epoch [6/100], Step [8/10], Loss: 0.4543, Dice Coef: 0.7855
# Epoch [6/100], Step [9/10], Loss: 0.5550, Dice Coef: 0.7219
# Epoch [6/100], Step [10/10], Loss: 1.1121, Dice Coef: 0.4470
# Epoch [7/100], Step [1/10], Loss: 0.5623, Dice Coef: 0.7042
# Epoch [7/100], Step [2/10], Loss: 0.5668, Dice Coef: 0.7306
# Epoch [7/100], Step [3/10], Loss: 0.5505, Dice Coef: 0.7448
# Epoch [7/100], Step [4/10], Loss: 0.5305, Dice Coef: 0.7376
# Epoch [7/100], Step [5/10], Loss: 0.5289, Dice Coef: 0.7445
# Epoch [7/100], Step [6/10], Loss: 0.4914, Dice Coef: 0.7678
# Epoch [7/100], Step [7/10], Loss: 0.6210, Dice Coef: 0.7027
# Epoch [7/100], Step [8/10], Loss: 0.6411, Dice Coef: 0.6701
# Epoch [7/100], Step [9/10], Loss: 0.6249, Dice Coef: 0.6727
# Epoch [7/100], Step [10/10], Loss: 0.7602, Dice Coef: 0.5958
# Epoch [8/100], Step [1/10], Loss: 0.5139, Dice Coef: 0.7432
# Epoch [8/100], Step [2/10], Loss: 0.5306, Dice Coef: 0.7473
# Epoch [8/100], Step [3/10], Loss: 0.5002, Dice Coef: 0.7747
# Epoch [8/100], Step [4/10], Loss: 0.5412, Dice Coef: 0.7214
# Epoch [8/100], Step [5/10], Loss: 0.5411, Dice Coef: 0.7249
# Epoch [8/100], Step [6/10], Loss: 0.6336, Dice Coef: 0.6685
# Epoch [8/100], Step [7/10], Loss: 0.5275, Dice Coef: 0.7432
# Epoch [8/100], Step [8/10], Loss: 0.4855, Dice Coef: 0.7542
# Epoch [8/100], Step [9/10], Loss: 0.5143, Dice Coef: 0.7451
# Epoch [8/100], Step [10/10], Loss: 0.8302, Dice Coef: 0.5795
# Epoch [9/100], Step [1/10], Loss: 0.5175, Dice Coef: 0.7607
# Epoch [9/100], Step [2/10], Loss: 0.4929, Dice Coef: 0.7567
# Epoch [9/100], Step [3/10], Loss: 0.5544, Dice Coef: 0.7175
# Epoch [9/100], Step [4/10], Loss: 0.5719, Dice Coef: 0.7082
# Epoch [9/100], Step [5/10], Loss: 0.4476, Dice Coef: 0.7794
# Epoch [9/100], Step [6/10], Loss: 0.6013, Dice Coef: 0.6864
# Epoch [9/100], Step [7/10], Loss: 0.5165, Dice Coef: 0.7392
# Epoch [9/100], Step [8/10], Loss: 0.5032, Dice Coef: 0.7475
# Epoch [9/100], Step [9/10], Loss: 0.4708, Dice Coef: 0.7599
# Epoch [9/100], Step [10/10], Loss: 0.4110, Dice Coef: 0.8126
# Epoch [10/100], Step [1/10], Loss: 0.5370, Dice Coef: 0.7168
# Epoch [10/100], Step [2/10], Loss: 0.4712, Dice Coef: 0.7668
# Epoch [10/100], Step [3/10], Loss: 0.4338, Dice Coef: 0.7806
# Epoch [10/100], Step [4/10], Loss: 0.7889, Dice Coef: 0.6480
# Epoch [10/100], Step [5/10], Loss: 0.4732, Dice Coef: 0.7714
# Epoch [10/100], Step [6/10], Loss: 0.4825, Dice Coef: 0.7716
# Epoch [10/100], Step [7/10], Loss: 0.5432, Dice Coef: 0.7129
# Epoch [10/100], Step [8/10], Loss: 0.4644, Dice Coef: 0.7663
# Epoch [10/100], Step [9/10], Loss: 0.4337, Dice Coef: 0.7949
# Epoch [10/100], Step [10/10], Loss: 0.4870, Dice Coef: 0.7659
# Epoch [11/100], Step [1/10], Loss: 0.4111, Dice Coef: 0.7967
# Epoch [11/100], Step [2/10], Loss: 0.4335, Dice Coef: 0.7956
# Epoch [11/100], Step [3/10], Loss: 0.5043, Dice Coef: 0.7459
# Epoch [11/100], Step [4/10], Loss: 0.5861, Dice Coef: 0.7185
# Epoch [11/100], Step [5/10], Loss: 0.5696, Dice Coef: 0.7261
# Epoch [11/100], Step [6/10], Loss: 0.4263, Dice Coef: 0.7920
# Epoch [11/100], Step [7/10], Loss: 0.4607, Dice Coef: 0.7890
# Epoch [11/100], Step [8/10], Loss: 0.4288, Dice Coef: 0.7879
# Epoch [11/100], Step [9/10], Loss: 0.8051, Dice Coef: 0.5905
# Epoch [11/100], Step [10/10], Loss: 0.4706, Dice Coef: 0.7630
# Epoch [12/100], Step [1/10], Loss: 0.5323, Dice Coef: 0.7221
# Epoch [12/100], Step [2/10], Loss: 0.5786, Dice Coef: 0.6946
# Epoch [19/100], Step [10/10], Loss: 0.4039, Dice Coef: 0.7826
# Epoch [20/100], Step [1/10], Loss: 0.3738, Dice Coef: 0.8255
# Epoch [20/100], Step [2/10], Loss: 0.4594, Dice Coef: 0.7543
# Epoch [20/100], Step [3/10], Loss: 0.4338, Dice Coef: 0.7710
# Epoch [20/100], Step [4/10], Loss: 0.3741, Dice Coef: 0.8043
# Epoch [20/100], Step [5/10], Loss: 0.3588, Dice Coef: 0.8271
# Epoch [20/100], Step [6/10], Loss: 0.3872, Dice Coef: 0.7971
# Epoch [20/100], Step [7/10], Loss: 0.4315, Dice Coef: 0.7703
# Epoch [20/100], Step [8/10], Loss: 0.3372, Dice Coef: 0.8340
# Epoch [20/100], Step [9/10], Loss: 0.6182, Dice Coef: 0.6892
# Epoch [20/100], Step [10/10], Loss: 0.4415, Dice Coef: 0.7928
# Epoch [21/100], Step [1/10], Loss: 0.3411, Dice Coef: 0.8450
# Epoch [21/100], Step [2/10], Loss: 0.4632, Dice Coef: 0.7662
# Epoch [21/100], Step [3/10], Loss: 0.4254, Dice Coef: 0.7835
# Epoch [21/100], Step [4/10], Loss: 0.3638, Dice Coef: 0.8200
# Epoch [21/100], Step [5/10], Loss: 0.3369, Dice Coef: 0.8370
# Epoch [21/100], Step [6/10], Loss: 0.3790, Dice Coef: 0.8000
# Epoch [21/100], Step [7/10], Loss: 0.3485, Dice Coef: 0.8243
# Epoch [21/100], Step [8/10], Loss: 0.3705, Dice Coef: 0.8074
# Epoch [21/100], Step [9/10], Loss: 0.4833, Dice Coef: 0.7444
# Epoch [21/100], Step [10/10], Loss: 0.9265, Dice Coef: 0.4773
# Epoch [22/100], Step [1/10], Loss: 0.3645, Dice Coef: 0.8144
# Epoch [22/100], Step [2/10], Loss: 0.4320, Dice Coef: 0.7696
# Epoch [22/100], Step [3/10], Loss: 0.4592, Dice Coef: 0.7580
# Epoch [22/100], Step [4/10], Loss: 0.3679, Dice Coef: 0.8062
# Epoch [22/100], Step [5/10], Loss: 0.3529, Dice Coef: 0.8206
# Epoch [22/100], Step [6/10], Loss: 0.3769, Dice Coef: 0.8120
# Epoch [22/100], Step [7/10], Loss: 0.3632, Dice Coef: 0.8144
# Epoch [22/100], Step [8/10], Loss: 0.4123, Dice Coef: 0.7844
# Epoch [22/100], Step [9/10], Loss: 0.3621, Dice Coef: 0.8119
# Epoch [22/100], Step [10/10], Loss: 0.4504, Dice Coef: 0.7654
# Epoch [23/100], Step [1/10], Loss: 0.3174, Dice Coef: 0.8421
# Epoch [23/100], Step [2/10], Loss: 0.3830, Dice Coef: 0.8085
# Epoch [23/100], Step [3/10], Loss: 0.4192, Dice Coef: 0.7896
# Epoch [23/100], Step [4/10], Loss: 0.3509, Dice Coef: 0.8221
# Epoch [23/100], Step [5/10], Loss: 0.3675, Dice Coef: 0.8114
# Epoch [23/100], Step [6/10], Loss: 0.3426, Dice Coef: 0.8286
# Epoch [23/100], Step [7/10], Loss: 0.3359, Dice Coef: 0.8303
# Epoch [23/100], Step [8/10], Loss: 0.4736, Dice Coef: 0.7555
# Epoch [39/100], Step [3/10], Loss: 0.2767, Dice Coef: 0.8578
# Epoch [39/100], Step [4/10], Loss: 0.2655, Dice Coef: 0.8696
# Epoch [39/100], Step [5/10], Loss: 0.3044, Dice Coef: 0.8544
# Epoch [39/100], Step [6/10], Loss: 0.2512, Dice Coef: 0.8720
# Epoch [39/100], Step [7/10], Loss: 0.2586, Dice Coef: 0.8713
# Epoch [39/100], Step [8/10], Loss: 0.3558, Dice Coef: 0.8062
# Epoch [39/100], Step [9/10], Loss: 0.4211, Dice Coef: 0.7720
# Epoch [39/100], Step [10/10], Loss: 0.4055, Dice Coef: 0.7740
# Epoch [40/100], Step [1/10], Loss: 0.2503, Dice Coef: 0.8720
# Epoch [40/100], Step [2/10], Loss: 0.2796, Dice Coef: 0.8568
# Epoch [40/100], Step [3/10], Loss: 0.2893, Dice Coef: 0.8459
# Epoch [40/100], Step [4/10], Loss: 0.2356, Dice Coef: 0.8852
# Epoch [40/100], Step [5/10], Loss: 0.3527, Dice Coef: 0.8065
# Epoch [40/100], Step [6/10], Loss: 0.2358, Dice Coef: 0.8771
# Epoch [40/100], Step [7/10], Loss: 0.3044, Dice Coef: 0.8329
# Epoch [40/100], Step [8/10], Loss: 0.2988, Dice Coef: 0.8482
# Epoch [40/100], Step [9/10], Loss: 0.2657, Dice Coef: 0.8583
# Epoch [40/100], Step [10/10], Loss: 0.2315, Dice Coef: 0.8761
# Epoch [41/100], Step [1/10], Loss: 0.3509, Dice Coef: 0.8131
# Epoch [41/100], Step [2/10], Loss: 0.2533, Dice Coef: 0.8660
# Epoch [41/100], Step [3/10], Loss: 0.2825, Dice Coef: 0.8440
# Epoch [41/100], Step [4/10], Loss: 0.2980, Dice Coef: 0.8402
# Epoch [41/100], Step [5/10], Loss: 0.3577, Dice Coef: 0.8137
# Epoch [41/100], Step [6/10], Loss: 0.2872, Dice Coef: 0.8469
# Epoch [41/100], Step [7/10], Loss: 0.2650, Dice Coef: 0.8834
# Epoch [41/100], Step [8/10], Loss: 0.2312, Dice Coef: 0.8854
# Epoch [41/100], Step [9/10], Loss: 0.2332, Dice Coef: 0.8818
# Epoch [41/100], Step [10/10], Loss: 0.4393, Dice Coef: 0.7766
# Epoch [42/100], Step [1/10], Loss: 0.3491, Dice Coef: 0.8088
# Epoch [42/100], Step [2/10], Loss: 0.3292, Dice Coef: 0.8248
# Epoch [42/100], Step [3/10], Loss: 0.2528, Dice Coef: 0.8869
# Epoch [42/100], Step [4/10], Loss: 0.2565, Dice Coef: 0.8768
# Epoch [42/100], Step [5/10], Loss: 0.2762, Dice Coef: 0.8606
# Epoch [42/100], Step [6/10], Loss: 0.3487, Dice Coef: 0.8152
# Epoch [42/100], Step [7/10], Loss: 0.2283, Dice Coef: 0.8899
# Epoch [42/100], Step [8/10], Loss: 0.3540, Dice Coef: 0.8371
# Epoch [42/100], Step [9/10], Loss: 0.3099, Dice Coef: 0.8297
# Epoch [42/100], Step [10/10], Loss: 0.3557, Dice Coef: 0.8011
# Epoch [43/100], Step [1/10], Loss: 0.3209, Dice Coef: 0.8215
# Epoch [43/100], Step [2/10], Loss: 0.2694, Dice Coef: 0.8609
# Epoch [43/100], Step [3/10], Loss: 0.3609, Dice Coef: 0.7950
# Epoch [43/100], Step [4/10], Loss: 0.2654, Dice Coef: 0.8632
# Epoch [43/100], Step [5/10], Loss: 0.2889, Dice Coef: 0.8481
# Epoch [43/100], Step [6/10], Loss: 0.2319, Dice Coef: 0.8860
# Epoch [43/100], Step [7/10], Loss: 0.2461, Dice Coef: 0.8668
# Epoch [43/100], Step [8/10], Loss: 0.2262, Dice Coef: 0.8860
# Epoch [43/100], Step [9/10], Loss: 0.2685, Dice Coef: 0.8610
# Epoch [43/100], Step [10/10], Loss: 0.2525, Dice Coef: 0.8785
# Epoch [44/100], Step [1/10], Loss: 0.2481, Dice Coef: 0.8688
# Epoch [44/100], Step [2/10], Loss: 0.2876, Dice Coef: 0.8518
# Epoch [44/100], Step [3/10], Loss: 0.2289, Dice Coef: 0.8817
# Epoch [44/100], Step [4/10], Loss: 0.3264, Dice Coef: 0.8324
# Epoch [44/100], Step [5/10], Loss: 0.2045, Dice Coef: 0.8991
# Epoch [44/100], Step [6/10], Loss: 0.2718, Dice Coef: 0.8614
# Epoch [44/100], Step [7/10], Loss: 0.2612, Dice Coef: 0.8799
# Epoch [44/100], Step [8/10], Loss: 0.3337, Dice Coef: 0.8113
# Epoch [44/100], Step [9/10], Loss: 0.2788, Dice Coef: 0.8499
# Epoch [44/100], Step [10/10], Loss: 0.3411, Dice Coef: 0.8106
# Epoch [45/100], Step [1/10], Loss: 0.2777, Dice Coef: 0.8616
# Epoch [45/100], Step [2/10], Loss: 0.2354, Dice Coef: 0.8729
# Epoch [45/100], Step [3/10], Loss: 0.2717, Dice Coef: 0.8552
# Epoch [45/100], Step [4/10], Loss: 0.2519, Dice Coef: 0.8662
# Epoch [45/100], Step [5/10], Loss: 0.2937, Dice Coef: 0.8466
# Epoch [45/100], Step [6/10], Loss: 0.2237, Dice Coef: 0.8882
# Epoch [45/100], Step [7/10], Loss: 0.3133, Dice Coef: 0.8328
# Epoch [45/100], Step [8/10], Loss: 0.2234, Dice Coef: 0.8831
# Epoch [45/100], Step [9/10], Loss: 0.2401, Dice Coef: 0.8888
# Epoch [45/100], Step [10/10], Loss: 0.5151, Dice Coef: 0.6985
# Epoch [46/100], Step [1/10], Loss: 0.2263, Dice Coef: 0.8878
# Epoch [46/100], Step [2/10], Loss: 0.2981, Dice Coef: 0.8327
# Epoch [46/100], Step [3/10], Loss: 0.2442, Dice Coef: 0.8724
# Epoch [46/100], Step [4/10], Loss: 0.2563, Dice Coef: 0.8689
# Epoch [46/100], Step [5/10], Loss: 0.3934, Dice Coef: 0.7888
# Epoch [46/100], Step [6/10], Loss: 0.2336, Dice Coef: 0.8805
# Epoch [46/100], Step [7/10], Loss: 0.2261, Dice Coef: 0.8847
# Epoch [46/100], Step [8/10], Loss: 0.2065, Dice Coef: 0.9034
# Epoch [81/100], Step [6/10], Loss: 0.1646, Dice Coef: 0.9151
# Epoch [81/100], Step [7/10], Loss: 0.1330, Dice Coef: 0.9347
# Epoch [81/100], Step [8/10], Loss: 0.1192, Dice Coef: 0.9448
# Epoch [81/100], Step [9/10], Loss: 0.1845, Dice Coef: 0.8997
# Epoch [81/100], Step [10/10], Loss: 0.1413, Dice Coef: 0.9276
# Epoch [82/100], Step [1/10], Loss: 0.1617, Dice Coef: 0.9118
# Epoch [82/100], Step [2/10], Loss: 0.1214, Dice Coef: 0.9431
# Epoch [82/100], Step [3/10], Loss: 0.1217, Dice Coef: 0.9442
# Epoch [82/100], Step [4/10], Loss: 0.1521, Dice Coef: 0.9197
# Epoch [82/100], Step [5/10], Loss: 0.1513, Dice Coef: 0.9204
# Epoch [82/100], Step [6/10], Loss: 0.1578, Dice Coef: 0.9245
# Epoch [82/100], Step [7/10], Loss: 0.1474, Dice Coef: 0.9302
# Epoch [82/100], Step [8/10], Loss: 0.2982, Dice Coef: 0.8269
# Epoch [82/100], Step [9/10], Loss: 0.2318, Dice Coef: 0.8642
# Epoch [82/100], Step [10/10], Loss: 0.1626, Dice Coef: 0.9105
# Epoch [83/100], Step [1/10], Loss: 0.1357, Dice Coef: 0.9383
# Epoch [83/100], Step [2/10], Loss: 0.1374, Dice Coef: 0.9436
# Epoch [83/100], Step [3/10], Loss: 0.1634, Dice Coef: 0.9108
# Epoch [83/100], Step [4/10], Loss: 0.1362, Dice Coef: 0.9342
# Epoch [83/100], Step [5/10], Loss: 0.1667, Dice Coef: 0.9082
# Epoch [83/100], Step [6/10], Loss: 0.1758, Dice Coef: 0.9017
# Epoch [83/100], Step [7/10], Loss: 0.2027, Dice Coef: 0.8833
# Epoch [83/100], Step [8/10], Loss: 0.1914, Dice Coef: 0.8931
# Epoch [83/100], Step [9/10], Loss: 0.1916, Dice Coef: 0.8948
# Epoch [83/100], Step [10/10], Loss: 0.1434, Dice Coef: 0.9270
# Epoch [84/100], Step [1/10], Loss: 0.1239, Dice Coef: 0.9363
# Epoch [84/100], Step [2/10], Loss: 0.2456, Dice Coef: 0.8504
# Epoch [84/100], Step [3/10], Loss: 0.1556, Dice Coef: 0.9177
# Epoch [84/100], Step [4/10], Loss: 0.1317, Dice Coef: 0.9332
# Epoch [84/100], Step [5/10], Loss: 0.1619, Dice Coef: 0.9129
# Epoch [84/100], Step [6/10], Loss: 0.1501, Dice Coef: 0.9234
# Epoch [84/100], Step [7/10], Loss: 0.1310, Dice Coef: 0.9341
# Epoch [84/100], Step [8/10], Loss: 0.1582, Dice Coef: 0.9166
# Epoch [84/100], Step [9/10], Loss: 0.1429, Dice Coef: 0.9276
# Epoch [84/100], Step [10/10], Loss: 0.1494, Dice Coef: 0.9316
# Epoch [85/100], Step [1/10], Loss: 0.1340, Dice Coef: 0.9335
# Epoch [85/100], Step [2/10], Loss: 0.1434, Dice Coef: 0.9234
# Epoch [85/100], Step [3/10], Loss: 0.2174, Dice Coef: 0.8735
# Epoch [96/100], Step [9/10], Loss: 0.1156, Dice Coef: 0.9416
# Epoch [96/100], Step [10/10], Loss: 0.1523, Dice Coef: 0.9301
# Epoch [97/100], Step [1/10], Loss: 0.1454, Dice Coef: 0.9233
# Epoch [97/100], Step [2/10], Loss: 0.2116, Dice Coef: 0.8758
# Epoch [97/100], Step [3/10], Loss: 0.1121, Dice Coef: 0.9452
# Epoch [97/100], Step [4/10], Loss: 0.1522, Dice Coef: 0.9141
# Epoch [97/100], Step [5/10], Loss: 0.1138, Dice Coef: 0.9473
# Epoch [97/100], Step [6/10], Loss: 0.1606, Dice Coef: 0.9073
# Epoch [97/100], Step [7/10], Loss: 0.1223, Dice Coef: 0.9371
# Epoch [97/100], Step [8/10], Loss: 0.1227, Dice Coef: 0.9344
# Epoch [97/100], Step [9/10], Loss: 0.1078, Dice Coef: 0.9462
# Epoch [97/100], Step [10/10], Loss: 0.1163, Dice Coef: 0.9557
# Epoch [98/100], Step [1/10], Loss: 0.1903, Dice Coef: 0.8977
# Epoch [98/100], Step [2/10], Loss: 0.1315, Dice Coef: 0.9439
# Epoch [98/100], Step [3/10], Loss: 0.1848, Dice Coef: 0.9048
# Epoch [98/100], Step [4/10], Loss: 0.1235, Dice Coef: 0.9351
# Epoch [98/100], Step [5/10], Loss: 0.1663, Dice Coef: 0.9058
# Epoch [98/100], Step [6/10], Loss: 0.1287, Dice Coef: 0.9322
# Epoch [98/100], Step [7/10], Loss: 0.1452, Dice Coef: 0.9344
# Epoch [98/100], Step [8/10], Loss: 0.0971, Dice Coef: 0.9585
# Epoch [98/100], Step [9/10], Loss: 0.1931, Dice Coef: 0.8837
# Epoch [98/100], Step [10/10], Loss: 0.0972, Dice Coef: 0.9568
# Epoch [99/100], Step [1/10], Loss: 0.0962, Dice Coef: 0.9576
# Epoch [99/100], Step [2/10], Loss: 0.1446, Dice Coef: 0.9246
# Epoch [99/100], Step [3/10], Loss: 0.1660, Dice Coef: 0.9095
# Epoch [99/100], Step [4/10], Loss: 0.1072, Dice Coef: 0.9489
# Epoch [99/100], Step [5/10], Loss: 0.1091, Dice Coef: 0.9484
# Epoch [99/100], Step [6/10], Loss: 0.1077, Dice Coef: 0.9475
# Epoch [99/100], Step [7/10], Loss: 0.1371, Dice Coef: 0.9236
# Epoch [99/100], Step [8/10], Loss: 0.2039, Dice Coef: 0.8809
# Epoch [99/100], Step [9/10], Loss: 0.1216, Dice Coef: 0.9388
# Epoch [99/100], Step [10/10], Loss: 0.3136, Dice Coef: 0.7956
# Epoch [100/100], Step [1/10], Loss: 0.1785, Dice Coef: 0.8961
# Epoch [100/100], Step [2/10], Loss: 0.1360, Dice Coef: 0.9261
# Epoch [100/100], Step [3/10], Loss: 0.1312, Dice Coef: 0.9338
# Epoch [100/100], Step [4/10], Loss: 0.1062, Dice Coef: 0.9469
# Epoch [100/100], Step [5/10], Loss: 0.1877, Dice Coef: 0.8883
# Epoch [100/100], Step [6/10], Loss: 0.1234, Dice Coef: 0.9327
# Epoch [100/100], Step [7/10], Loss: 0.0953, Dice Coef: 0.9530
# Epoch [100/100], Step [8/10], Loss: 0.1156, Dice Coef: 0.9408
# Epoch [100/100], Step [9/10], Loss: 0.1084, Dice Coef: 0.9466
# Epoch [100/100], Step [10/10], Loss: 0.0984, Dice Coef: 0.9552

# %%
metrics = trainer.get_metrics()

# %%
def to_numpy(tensor):
    # Move tensor to CPU and convert to NumPy array
    return tensor.cpu().detach().item()

def plot_metrics(metrics):
    num_epochs = len(metrics['train_losses'])
    epochs = np.arange(1, num_epochs + 1)

    # Convert tensors to NumPy arrays
    train_losses_np = metrics['train_losses']
    val_losses_np = metrics['val_losses']
    train_dices_np = [to_numpy(dice) for dice in metrics['train_dices']]
    val_dices_np = [to_numpy(dice) for dice in metrics['val_dices']]
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses_np, label='Train Loss')
    plt.plot(epochs, val_losses_np, label='Val Loss')
    plt.title('Training and Validation Losses')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Dice Coefficients
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_dices_np, label='Train Dice')
    plt.plot(epochs, val_dices_np, label='Val Dice')
    plt.title('Training and Validation Dice Coefficients')
    plt.xlabel('Epoch')
    plt.ylabel('Dice Coefficient')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_metrics(metrics)

# %%
import matplotlib.pyplot as plt
import numpy as np

def to_numpy(tensor):
    # Move tensor to CPU and convert to NumPy array
    return tensor.cpu().detach().numpy()

def threshold_prediction(predicted, threshold=0.5):
    # Threshold predicted values
    predicted[predicted < threshold] = 0
    predicted[predicted >= threshold] = 1
    return predicted

def plot_subplots(image, mask, predicted, threshold=0.5):
    # Convert tensors to NumPy arrays
    image_np, mask_np, predicted_np = map(to_numpy, (image, mask, predicted))

    # Threshold the predicted values
    predicted_np_thresholded = threshold_prediction(predicted_np, threshold)

    fig, axes = plt.subplots(1, 3, figsize=(10, 5))  # Adjust figsize as needed

    # Plot Image, Mask, Predicted, and Thresholded Predicted
    titles = ['Image', 'Mask', 'Predicted']
    for ax, data, title in zip(axes, [image_np, mask_np, predicted_np, predicted_np_thresholded], titles):
        ax.imshow(data.squeeze(), cmap='gray' if 'Mask' in title else 'gray')
        ax.set_title(title)
        ax.axis('off')

    plt.show()

# %%
import matplotlib.pyplot as plt
from skimage.measure import label
from PIL import Image
import cv2

i = random.randint(20,40)
image = train_dataset[i][0]
mask = train_dataset[i][1]
im = image.to(DEVICE)
pred = unet(im.unsqueeze(0))
pred = pred.squeeze()
# plot are

plot_subplots(im, mask, pred)

# %%
#i = random.randint(20,40)
i=20
image = train_dataset[i][0]
mask = train_dataset[i][1]
im = image.to(DEVICE)
pred = unet(im.unsqueeze(0))
pred = pred.squeeze()
# plot are

plot_subplots(im, mask, pred)
image = np.array(image)
image.squeeze()
print(image.shape)

binary_matrix = (pred > 0.5).to(torch.uint8)

binary_matrix = binary_matrix.cpu().numpy()
mask = binary_matrix
label_image = label(mask)
bbox = label_image.nonzero()
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.imshow(image.squeeze())
rect = plt.Rectangle((bbox[1].min(), bbox[0].min()), bbox[1].max()-bbox[1].min(), bbox[0].max()-bbox[0].min(), linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(rect)
plt.show()
# Out:
# (1, 128, 128)
